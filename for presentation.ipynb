# %% [markdown]
# """
# Title: Analyse Potential Factors Affecting Forest Cover Rate of Different Countries
#
# team member: Jiawei Zhao
#
# Github ID: vivizhao95
#
# Hypothesis 1: there would be a negative correlation between the  agriculture land hold by a country and the forest coverage.
#
# Hypothesis 2: there would be a negative correlation between the GDP and the forest coverage of a country.
#
# Hypothesis 3: if a country consumes more meat per capita, the country would have a lower forest coverage.
#
# source:
#
# 1. Agricultural land (% of land area)
#
# https://data.worldbank.org/indicator/ag.lnd.frst.zs
#
# 2. Forest land (% of land area)
#
# https://data.worldbank.org/indicator/AG.LND.AGRI.ZS
#
# 3. GDP by country
#
# https://www.kaggle.com/jtennis/gdp-by-country-the-maddisonproject/data
#
# 4. Meat Consumption by country
#
# https://data.world/oecd/meat-consumption/workspace/file?filename=meat_consumption.csv
#
# """

# %% [markdown]
# project’s purpose, hypotheses, design reasoning, and results so far.

# %% [markdown]
# design reasoning:
#     1. focused too much on economic development, and overlooked the influences we brought to the nature
#     2. Hypothesis 1: if the proportion of the agriculture land in a country has been increasing, its forest coverage might decreased.
#     since my sample data has over 200 countries and regions, I decided to first work out the average change rate of each country's forest coverage and agriculture land coverage. Then, is the 2 change rates are the same direction, i can say they are positively correlated. Finally, calculated the percentage of Negative correlated and Positive Correlated to see whether the Hypothesis is correct.
#     3. Hypothesis 2: simply investigated the relationship between GDP and the forest coverage of a country.
#     4. Hypothesis 3: Since livestock requires agriculture lands, i guess if a country consumes more meat per capita, the country would have a lower forest coverage.

# %% [markdown]
# results so far:
# Hypothesis 1:
# nearly 70% of countries have a negative correlation between the  agriculture land coverage and the forest coverage.
# ![image.png](attachment:image.png)

# %% [markdown]
# Hypothesis 2:
# there is a moderate positive correlation between the GDP and the forest coverage of a country.
# ![image.png](attachment:image.png)

# %% [markdown]
# to see it more clearly, groupby the data by 'Income level':
# ![image.png](attachment:image.png)
# therefore, we may reject the second hypothesis as this plot shows a clear positive correlation between the 2 variables.

# %% [markdown]
# Hypothesis 3:
# there seems no correlation between the 2 variables:
# ![image.png](attachment:image.png)

# %% [markdown]
# even if we groupby the data by 'Income level', the result didnt change:
# ![image.png](attachment:image.png)
